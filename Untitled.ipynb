# %%
# %load_ext autoreload
# %autoreload 2
import openai_calls
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
string = """
Q: Which option do you prefer? 
- Option F: 69.0 dollars with 1.0% chance, 26.0 dollars with 99.0% chance. 
- Option J: 2.0 dollars with 75.0% chance, 94.0 dollars with 25.0% chance. 
"""

"""
"- Option F: 33% chance of 2,500 dollars (67% chance of 0 dollars).\n"\
"- Option J: 34% chance of 2,400 dollars (66% chance of 0 dollars).\n" +  "\nA: Option""""


response = openai_calls._get_completion(task1)

response.choices[0].text.strip(), response.choices[0].logprobs.top_logprobs[0]
# Out:
# ('J',
#  <OpenAIObject at 0x12610c468> JSON: {
#    " F": -1.0574074,
#    " J": -0.42982495
#  })

# %%
np.exp(-0.0049653705)
# Out:
# 0.995046936573948

# %%
import openai
import pandas as pd
import numpy as np

engine = "text-davinci-002"

def act(text):
    openai.api_key = "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"
    response = openai.Completion.create(
        engine = engine,
        prompt = text,
        max_tokens = 1,
        temperature = 0.0,
        logprobs=2,
    )
    
    print(response)
    return response.choices[0].text.strip(), response.choices[0].logprobs.top_logprobs[0]

tasks = []

default_question = "Q: Which option do you prefer?\n\n"

task1 = default_question + "- Option F: 33% chance at 2,500 dollars, a 66% chance at 2,400 dollars, and a 1% chance of 0 dollars.\n"\
"- Option J: Guaranteed 2,400 dollars.\n" +  "\nA: Option"
tasks.append(task1)


data = []
for i, task in enumerate(tasks):
    print(task)
    action, log_probs = act(task)
    print(log_probs)
    row = [i+1, action, log_probs[" F"], log_probs[" J"]]
    print(row)
    data.append(row)
df = pd.DataFrame(data, columns=['task', 'action', 'logprobA', 'logprobB'])
print(df)
# Out:
# Q: Which option do you prefer?
#
# - Option F: 33% chance at 2,500 dollars, a 66% chance at 2,400 dollars, and a 1% chance of 0 dollars.
# - Option J: Guaranteed 2,400 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           182
#         ],
#         "token_logprobs": [
#           -0.4370113
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -1.0441319,
#             " J": -0.4370113
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892542,
#   "id": "cmpl-5pEbOczFuURfJ83TsvcRAjMppee8T",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 59,
#     "total_tokens": 60
#   }
# }
# {
#   " F": -1.0441319,
#   " J": -0.4370113
# }
# [1, 'J', -1.0441319, -0.4370113]
# Q: Which option do you prefer?
#
# - Option F: 33% chance of 2,500 dollars (67% chance of 0 dollars).
# - Option J: 34% chance of 2,400 dollars (66% chance of 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           176
#         ],
#         "token_logprobs": [
#           -0.6149722
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.6149722,
#             " J": -0.780406
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892543,
#   "id": "cmpl-5pEbPROLdh4TkAwUU1MRfPOLIlGlb",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 56,
#     "total_tokens": 57
#   }
# }
# {
#   " F": -0.6149722,
#   " J": -0.780406
# }
# [2, 'F', -0.6149722, -0.780406]
# Q: Which option do you prefer?
#
# - Option F: 80% chance of 4,000 dollars (20% chance of 0 dollars).
# - Option J: 100% guarantee of 3,000 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           154
#         ],
#         "token_logprobs": [
#           -0.07595549
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -2.6352437,
#             " J": -0.07595549
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892543,
#   "id": "cmpl-5pEbPHNjf0ltDphMt0c5x9f1S1w7f",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 49,
#     "total_tokens": 50
#   }
# }
# {
#   " F": -2.6352437,
#   " J": -0.07595549
# }
# [3, 'J', -2.6352437, -0.07595549]
# Q: Which option do you prefer?
#
# - Option F: 20% chance of 4,000 dollars (80% chance of 0 dollars).
# - Option J: 25% chance of 3,000 dollars (75% chance of 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           176
#         ],
#         "token_logprobs": [
#           -0.3635272
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -1.1934146,
#             " J": -0.3635272
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892543,
#   "id": "cmpl-5pEbPsz7YmndJR6AGqjNqDiUWnAUZ",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 56,
#     "total_tokens": 57
#   }
# }
# {
#   " F": -1.1934146,
#   " J": -0.3635272
# }
# [4, 'J', -1.1934146, -0.3635272]
# Q: Which option do you prefer?
#
# - Option F: 45% chance of 6,000 dollars (55% chance of 0 dollars).
# - Option J: 90% chance of 3,000 dollars (10% chance of 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           176
#         ],
#         "token_logprobs": [
#           -0.04226135
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -3.2101936,
#             " J": -0.04226135
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892543,
#   "id": "cmpl-5pEbPQXPHsZtBARc3sIESq1ejYyM5",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 56,
#     "total_tokens": 57
#   }
# }
# {
#   " F": -3.2101936,
#   " J": -0.04226135
# }
# [5, 'J', -3.2101936, -0.04226135]
# Q: Which option do you prefer?
#
# - Option F: 0.1% chance of 6,000 dollars (99.9% chance of 0 dollars).
# - Option J: 0.2% chance of 3,000 dollars (99.8% chance of 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           182
#         ],
#         "token_logprobs": [
#           -0.38510618
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.38510618,
#             " J": -1.1457387
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892544,
#   "id": "cmpl-5pEbQt1Dh4pV9NzcWWKeCXJ3TDwiZ",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 64,
#     "total_tokens": 65
#   }
# }
# {
#   " F": -0.38510618,
#   " J": -1.1457387
# }
# [6, 'F', -0.38510618, -1.1457387]
# Q: Which option do you prefer?
#
# - Option F: 80% chance of losing 4,000 dollars (20% chance of losing 0 dollars).
# - Option J: 100% guarantee of losing 3,000 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           175
#         ],
#         "token_logprobs": [
#           -0.1691634
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.1691634,
#             " J": -1.8784931
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892544,
#   "id": "cmpl-5pEbQGAINRnPuP3oA3ei1OydptBnr",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 52,
#     "total_tokens": 53
#   }
# }
# {
#   " F": -0.1691634,
#   " J": -1.8784931
# }
# [7, 'F', -0.1691634, -1.8784931]
# Q: Which option do you prefer?
#
# - Option F: 20% chance of losing 4,000 dollars (80% chance of losing 0 dollars).
# - Option J: 25% chance of losing 3,000 dollars (75% chance of losing 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           204
#         ],
#         "token_logprobs": [
#           -0.5760417
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.5760417,
#             " J": -0.830109
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892544,
#   "id": "cmpl-5pEbQ7OCqox23UBhdXHM36CsiOozV",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 60,
#     "total_tokens": 61
#   }
# }
# {
#   " F": -0.5760417,
#   " J": -0.830109
# }
# [8, 'F', -0.5760417, -0.830109]
# Q: Which option do you prefer?
#
# - Option F: 45% chance of losing 6,000 dollars (55% chance of losing 0 dollars).
# - Option J: 90% chance of losing 3,000 dollars (10% chance of losing 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           204
#         ],
#         "token_logprobs": [
#           -0.4164379
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.4164379,
#             " J": -1.0847957
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892544,
#   "id": "cmpl-5pEbQGZOjl7rK5YQrKHEYFHTJsDBh",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 60,
#     "total_tokens": 61
#   }
# }
# {
#   " F": -0.4164379,
#   " J": -1.0847957
# }
# [9, 'F', -0.4164379, -1.0847957]
# Q: Which option do you prefer?
#
# - Option F: 0.1% chance of losing 6,000 dollars (99.9% chance of losing 0 dollars).
# - Option J: 0.2% chance of losing 3,000 dollars (99.8% chance of losing 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           210
#         ],
#         "token_logprobs": [
#           -0.45075157
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.45075157,
#             " J": -1.0185597
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892545,
#   "id": "cmpl-5pEbRuOqfETzefUpuZPtcVXiXqwab",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 68,
#     "total_tokens": 69
#   }
# }
# {
#   " F": -0.45075157,
#   " J": -1.0185597
# }
# [10, 'F', -0.45075157, -1.0185597]
# Imagine you are playing a game with two levels, but you have to make a choice about the second level before you know the outcome of the first. At the first level, there is a 75% chance that the game will end without you winning anything, and a 25% chance that you will advance to the second level.
#
# Q: What would you choose in the second level?
#
# - Option F: 80% chance of 4,000 dollars (20% chance of 0 dollars).
# - Option J: 100% guarantee of 3,000 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           468
#         ],
#         "token_logprobs": [
#           -0.66690797
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.72473496,
#             " J": -0.66690797
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892545,
#   "id": "cmpl-5pEbRQEnbHbVvP0saJnNkrHyvYbnT",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 119,
#     "total_tokens": 120
#   }
# }
# {
#   " F": -0.72473496,
#   " J": -0.66690797
# }
# [11, 'J', -0.72473496, -0.66690797]
# Imagine we gave you 1,000 dollars right now to play a game.
#
# Q: Which option do you prefer?
#
# - Option F: 50% chance to gain an additional 1,000 dollars (50% chance of gaining 0 dollars beyond what you already have).
# - Option J: 100% guarantee of gaining an additional 500 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           291
#         ],
#         "token_logprobs": [
#           -0.20574605
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -1.6880639,
#             " J": -0.20574605
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892546,
#   "id": "cmpl-5pEbSXOSPgjYSpzA0fDIszRXumVQW",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 76,
#     "total_tokens": 77
#   }
# }
# {
#   " F": -1.6880639,
#   " J": -0.20574605
# }
# [12, 'J', -1.6880639, -0.20574605]
# Imagine we gave you 2,000 dollars right now to play a game.
#
# Q: Which option do you prefer?
#
# - Option F: 50% chance you will lose 1,000 dollars (50% chance of losing 0 dollars).
# - Option J: 100% chance you will lose 500 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           239
#         ],
#         "token_logprobs": [
#           -0.60694486
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.79363143,
#             " J": -0.60694486
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892546,
#   "id": "cmpl-5pEbSReSh9o9boEdXoc0ggzyiEA6u",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 69,
#     "total_tokens": 70
#   }
# }
# {
#   " F": -0.79363143,
#   " J": -0.60694486
# }
# [13, 'J', -0.79363143, -0.60694486]
# Q: Which option do you prefer?
#
# - Option F: 25% chance of 6,000 dollars (75% chance of 0 dollars).
# - Option J: 25% chance of 4,000 dollars (25% chance of 2,000 dollars, 50% chance of 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           205
#         ],
#         "token_logprobs": [
#           -0.5247071
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.8999751,
#             " J": -0.5247071
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892546,
#   "id": "cmpl-5pEbSuxuX13NG4i61IQlBqbfkfOFY",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 65,
#     "total_tokens": 66
#   }
# }
# {
#   " F": -0.8999751,
#   " J": -0.5247071
# }
# [14, 'J', -0.8999751, -0.5247071]
# Q: Which option do you prefer?
#
# - Option F: 25% chance of losing 6,000 dollars (75% chance of losing nothing).
# - Option J: 25% chance of losing 4,000 dollars (25% chance of 2,000 dollars, 50% chance of 0 dollars).
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           224
#         ],
#         "token_logprobs": [
#           -0.27189735
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -1.4417677,
#             " J": -0.27189735
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892546,
#   "id": "cmpl-5pEbS0wUXWUYbIA6ZjXYCUl2GCll0",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 67,
#     "total_tokens": 68
#   }
# }
# {
#   " F": -1.4417677,
#   " J": -0.27189735
# }
# [15, 'J', -1.4417677, -0.27189735]
# Q: Which option do you prefer?
#
# - Option F: 0.1% chance at 5,000 dollars (99.9% chance of 0 dollars).
# - Option J: 100% guarantee of 5 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           153
#         ],
#         "token_logprobs": [
#           -0.12481854
#         ],
#         "tokens": [
#           " J"
#         ],
#         "top_logprobs": [
#           {
#             " F": -2.1549299,
#             " J": -0.12481854
#           }
#         ]
#       },
#       "text": " J"
#     }
#   ],
#   "created": 1662892547,
#   "id": "cmpl-5pEbT6dphhDEWhslasVkF26Ey7QwD",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 51,
#     "total_tokens": 52
#   }
# }
# {
#   " F": -2.1549299,
#   " J": -0.12481854
# }
# [16, 'J', -2.1549299, -0.12481854]
# Q: Which option do you prefer?
#
# - Option F: 0.1% chance of losing 5,000 dollars (99.9% chance of losing nothing).
# - Option J: 100% guarantee of losing 5 dollars.
#
# A: Option
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": {
#         "text_offset": [
#           172
#         ],
#         "token_logprobs": [
#           -0.110097855
#         ],
#         "tokens": [
#           " F"
#         ],
#         "top_logprobs": [
#           {
#             " F": -0.110097855,
#             " J": -2.28022
#           }
#         ]
#       },
#       "text": " F"
#     }
#   ],
#   "created": 1662892547,
#   "id": "cmpl-5pEbTjhPRUbqcyWmPCuwtEzdWfwRo",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 1,
#     "prompt_tokens": 53,
#     "total_tokens": 54
#   }
# }
# {
#   " F": -0.110097855,
#   " J": -2.28022
# }
# [17, 'F', -0.110097855, -2.28022]
#     task action  logprobA  logprobB
# 0      1      J -1.044132 -0.437011
# 1      2      F -0.614972 -0.780406
# 2      3      J -2.635244 -0.075955
# 3      4      J -1.193415 -0.363527
# 4      5      J -3.210194 -0.042261
# 5      6      F -0.385106 -1.145739
# 6      7      F -0.169163 -1.878493
# 7      8      F -0.576042 -0.830109
# 8      9      F -0.416438 -1.084796
# 9     10      F -0.450752 -1.018560
# 10    11      J -0.724735 -0.666908
# 11    12      J -1.688064 -0.205746
# 12    13      J -0.793631 -0.606945
# 13    14      J -0.899975 -0.524707
# 14    15      J -1.441768 -0.271897
# 15    16      J -2.154930 -0.124819
# 16    17      F -0.110098 -2.280220
